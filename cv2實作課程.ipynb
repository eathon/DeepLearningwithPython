# %% [markdown]
# <a href="https://colab.research.google.com/github/eathon/DeepLearningwithPython/blob/master/cv2%E5%AF%A6%E4%BD%9C%E8%AA%B2%E7%A8%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab import files
import os 
path = "/content/sample_data"
os.chdir(path)
os.listdir(path)
pwd = os.getcwd()
files.upload() # 上傳檔案
os.listdir(path)
print (pwd)
# Out:
#      <input type="file" id="files-f3ed4e72-8a67-4feb-96fd-433ccd56b581" name="files[]" multiple disabled />
#      <output id="result-f3ed4e72-8a67-4feb-96fd-433ccd56b581">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving conan_s_head.png to conan_s_head.png
# /content/sample_data

# %%
from google.colab import files
import os 
path = "/content/sample_data"
os.chdir(path)
pwd=os.listdir(path)
print (pwd)
image=cv2.imread('conan_s_head.png')
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread('conan_s_head.png'))
# Out:
# ['california_housing_train.csv', 'anscombe.json', 'mnist_train_small.csv', 'mnist_test.csv', 'README.md', 'california_housing_test.csv', 'conan_s_head.png']
